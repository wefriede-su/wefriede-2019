# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

website = 'https://www.basketball-reference.com/contracts/players.html'
salaries = pd.read_html(website)
salaries[0].columns = [ 'Rank', 'Player', 'Team', '2018-19', '2019-20', '2020-21', '2021-22', '2022-23', '2023-24', 'Signed_Using', 'Guaranteed']
salaries_df = pd.DataFrame(salaries[0])

website = 'https://www.basketball-reference.com/leagues/NBA_2019_per_game.html'
stats = pd.read_html(website)
stats_df = pd.DataFrame(stats[0])

salary_unused = 140000000
count = 0
salary_used = 0
luxury_tax = 0
players = []
print(salaries_df[['Player','Team','2018-19']])
while True:
    if count == 12:
        print("Maximum players reached.")
        break
    elif salary_used < 100000000:
        print(salaries_df[['Player','Team','2018-19']].sample(15))
        player = input("Enter a player: ")
        print(salaries_df[['Player','Team','2018-19']][salaries_df['Player'] == player].head(1))
        salary = int(input("Enter that player's salary: "))
        players.append(player)
        count = count + 1
        salary_used = salary_used + salary
        salary_unused = salary_unused - salary
        print("You have used $%d and have $%d left" % (salary_used, salary_unused))
    elif 100000000 < salary_used < 140000000:
        print(salaries_df[['Player','Team','2018-19']].sample(15))
        player = input("Enter a player: ")
        print(salaries_df[['Player','Team','2018-19']][salaries_df['Player'] == player].head(1))
        salary = int(input("Enter that player's salary: "))
        players.append(player)
        count = count + 1
        luxury_tax = 1.5*salary
        salary_used = salary_used + salary + luxury_tax
        salary_unused = salary_unused - salary - luxury_tax
        print("You are in the luxury tax. You have used $%d and have $%d left" % (salary_used, salary_unused))
    elif salary_used > 140000000:
        print("You have gone over and have to start again.")
        players = []
        salary_unused = 140000000
        count = 0
        salary_used = 0
        luxury_tax = 0

print(players)        
while True:
    player_search = input("Enter a player you selected or press 'quit': ")
    if player_search == 'quit':
        break
    elif player_search != 'quit':
        print(stats_df[['Player','Tm','PTS','TRB','AST','STL','BLK','TOV','FT%','eFG%','3P%']][stats_df['Player'] == player_search])
# Out:
#                  Player Team      2018-19
# 0         Stephen Curry  GSW  $37,457,154
# 1            Chris Paul  HOU  $35,654,150
# 2     Russell Westbrook  OKC  $35,654,150
# 3          LeBron James  LAL  $35,654,150
# 4         Blake Griffin  DET  $32,088,932
# 5        Gordon Hayward  BOS  $31,214,295
# 6            Kyle Lowry  TOR  $31,200,000
# 7           Paul George  OKC  $30,560,700
# 8           Mike Conley  MEM  $30,521,116
# 9          James Harden  HOU  $30,431,854
# 10         Kevin Durant  GSW  $30,000,000
# 11         Paul Millsap  DEN  $29,730,769
# 12           Al Horford  BOS  $28,928,710
# 13       Damian Lillard  POR  $27,977,689
# 14        DeMar DeRozan  SAS  $27,739,975
# 15           Chris Bosh  MIA  $26,837,720
# 16          Otto Porter  CHI  $26,011,913
# 17         Jrue Holiday  NOP  $25,976,111
# 18          CJ McCollum  POR  $25,759,766
# 19      Carmelo Anthony  ATL  $25,534,253
# 20               Salary  NaN          NaN
# 21               Player   Tm      2018-19
# 22       Andrew Wiggins  MIN  $25,467,250
# 23          Joel Embiid  PHI  $25,467,250
# 24         Bradley Beal  WAS  $25,434,263
# 25        Anthony Davis  NOP  $25,434,263
# 26       Andre Drummond  DET  $25,434,263
# 27     Hassan Whiteside  MIA  $25,434,263
# 28         Nikola Jokic  DEN  $24,605,181
# 29         Steven Adams  OKC  $24,157,304
# ..                  ...  ...          ...
# 594      JaKarr Sampson  CHI      $88,531
# 595      Henry Ellenson  NYK      $85,458
# 596         Gary Payton  WAS      $85,458
# 597       Scotty Hopson  OKC      $85,458
# 598       Charles Cooke  MIA      $76,236
# 599        Andre Ingram  LAL      $76,236
# 600        Kobi Simmons  CLE      $76,236
# 601  Donatas Motiejunas  SAS      $59,820
# 602  Shaquille Harrison  PHO      $50,000
# 603        Garlon Green  NOP      $50,000
# 604        Ray Spalding  PHO      $47,371
# 605       Chris Chiozza  HOU      $47,371
# 606          Cody Demps  SAC      $47,371
# 607        B.J. Johnson  SAC      $47,371
# 608       Emanuel Terry  PHO      $47,371
# 609     Richard Solomon  OKC      $47,371
# 610         Mitch Creek  MIN      $47,371
# 611       Emanuel Terry  MIA      $47,371
# 612       Dusty Hannahs  MEM      $47,371
# 613       Scott Machado  LAL      $47,371
# 614              Salary  NaN          NaN
# 615              Player   Tm      2018-19
# 616       Stephan Hicks  IND      $47,371
# 617      Tahjere McCall  BRK      $47,371
# 618       Jordan Sibert  ATL      $47,371
# 619     Isaac Humphries  ATL      $47,371
# 620       Emanuel Terry  DEN      $35,000
# 621       Troy Williams  NOP      $34,183
# 622       Terry Larrier  DAL       $6,000
# 623      Ding Yanyuhang  DAL       $4,737
#
# [624 rows x 3 columns]
#                Player Team      2018-19
# 621     Troy Williams  NOP      $34,183
# 412   DeAndre' Bembry  ATL   $1,634,640
# 265      Zach Collins  POR   $3,628,920
# 168        Joe Harris  BRK   $8,333,333
# 302        Thon Maker  DET   $2,799,720
# 342     Channing Frye  CLE   $2,393,887
# 327         T.J. Leaf  IND   $2,407,560
# 141  Robert Covington  MIN  $10,464,092
# 510      Jevon Carter  MEM     $838,464
# 506    Chasson Randle  WAS     $869,094
# 396         Ian Clark  NOP   $1,757,429
# 96         Jeremy Lin  ATL  $13,768,421
# 408         Josh Hart  LAL   $1,655,160
# 17       Jrue Holiday  NOP  $25,976,111
# 476      Dwayne Bacon  CHO   $1,378,242
# Enter a player: Greg Monroe
#           Player Team     2018-19
# 364  Greg Monroe  BRK  $2,165,481
# Enter that player's salary: 1
# You have used $1 and have $139999999 left
#                   Player Team      2018-19
# 237  Willie Cauley-Stein  SAC   $4,696,875
# 49         Jabari Parker  WAS  $20,000,000
# 358        Darius Miller  NOP   $2,205,000
# 558           Quincy Acy  PHO     $213,949
# 94       Marvin Williams  CHO  $14,087,500
# 210        Jaren Jackson  MEM   $5,915,040
# 261           J.J. Barea  DAL   $3,710,850
# 242      Lauri Markkanen  CHI   $4,536,120
# 394               Salary  NaN          NaN
# 426        Jahlil Okafor  NOP   $1,567,007
# 547          C.J. Watson  ORL     $333,333
# 588         B.J. Johnson  ATL      $94,742
# 515       Isaiah Briscoe  ORL     $838,464
# 418          Tim Frazier  NOP   $1,621,415
# 375        Spencer Hawes  MIL   $2,007,058
# Enter a player: Jahlil Okafor
#             Player Team     2018-19
# 426  Jahlil Okafor  NOP  $1,567,007
# Enter that player's salary: 1
# You have used $2 and have $139999998 left
#                  Player Team      2018-19
# 142            Rudy Gay  SAS  $10,087,200
# 518  Isaiah Hartenstein  HOU     $838,464
# 44     Danilo Gallinari  LAC  $21,587,579
# 16          Otto Porter  CHI  $26,011,913
# 54          George Hill  MIL  $19,000,000
# 393        Nerlens Noel  OKC   $1,757,429
# 132         John Henson  CLE  $11,327,466
# 541      Malcolm Miller  TOR     $457,418
# 460              Salary  NaN          NaN
# 220   Patrick Patterson  OKC   $5,451,600
# 414         James Ennis  PHI   $1,621,415
# 178  Karl-Anthony Towns  MIN   $7,839,435
# 43               Player   Tm      2018-19
# 380          OG Anunoby  TOR   $1,952,760
# 211      Brandon Ingram  LAL   $5,757,120
# Enter a player: Jahlil Okafor
#             Player Team     2018-19
# 426  Jahlil Okafor  NOP  $1,567,007
# Enter that player's salary: 1
# You have used $3 and have $139999997 left
#               Player Team      2018-19
# 261       J.J. Barea  DAL   $3,710,850
# 457    Thomas Bryant  WAS   $1,378,242
# 430  Skal Labissiere  POR   $1,544,951
# 438           Salary  NaN          NaN
# 122     Kemba Walker  CHO  $12,000,000
# 393     Nerlens Noel  OKC   $1,757,429
# 256     Al Jefferson  IND   $4,000,000
# 110   Nikola Vucevic  ORL  $12,750,000
# 12        Al Horford  BOS  $28,928,710
# 252        Kris Dunn  CHI   $4,221,000
# 172   Garrett Temple  LAC   $8,000,000
# 98    Kenneth Faried  BRK  $13,764,045
# 500    Isaiah Taylor  CLE     $950,000
# 218           Salary  NaN          NaN
# 305       Sam Dekker  WAS   $2,760,095
# Enter a player: Jahlil Okafor
#             Player Team     2018-19
# 426  Jahlil Okafor  NOP  $1,567,007
# Enter that player's salary: 1
# You have used $4 and have $139999996 left
#                  Player Team      2018-19
# 288       Miles Bridges  CHO   $3,206,640
# 72       Derrick Favors  UTA  $16,900,000
# 554         Okaro White  WAS     $264,919
# 559         Tim Frazier  MIL     $205,098
# 136    Maurice Harkless  POR  $10,837,079
# 489  Shaquille Harrison  CHI   $1,311,265
# 329              Player   Tm      2018-19
# 540       Chris Boucher  TOR     $457,418
# 402        Jonah Bolden  PHI   $1,690,000
# 170       Deandre Ayton  PHO   $8,165,160
# 204     Marco Belinelli  SAS   $6,153,846
# 387       Larry Sanders  MIL   $1,865,547
# 244        Kyle O'Quinn  IND   $4,449,000
# 478        Daniel Theis  BOS   $1,378,242
# 485    Alfonzo McKinnie  GSW   $1,349,383
# Enter a player: Jahlil Okafor
#             Player Team     2018-19
# 426  Jahlil Okafor  NOP  $1,567,007
# Enter that player's salary: 1
# You have used $5 and have $139999995 left
#                 Player Team      2018-19
# 48        Kyrie Irving  BOS  $20,099,189
# 522    Martell Webster  WAS     $833,333
# 157      E'Twaun Moore  NOP   $8,808,685
# 325         Tyus Jones  MIN   $2,444,053
# 413        Dzanan Musa  BRK   $1,632,240
# 80        Clint Capela  HOU  $15,293,104
# 441       Wade Baldwin  IND   $1,544,951
# 171       Lou Williams  LAC   $8,000,000
# 165  Cristiano Felicio  CHI   $8,470,980
# 273    Justise Winslow  MIA   $3,448,926
# 226         Josh Smith  DET   $5,331,729
# 526             Salary  NaN          NaN
# 27    Hassan Whiteside  MIA  $25,434,263
# 498       Kyle Singler  OKC     $999,200
# 558         Quincy Acy  PHO     $213,949
# Enter a player: Jahlil Okafor
#             Player Team     2018-19
# 426  Jahlil Okafor  NOP  $1,567,007
# Enter that player's salary: 1
# You have used $6 and have $139999994 left
#               Player Team      2018-19
# 583     John Jenkins  WAS      $99,290
# 551       Nick Young  DEN     $311,070
# 532   Carlos Delfino  LAC     $650,000
# 133        Omer Asik  CHI  $11,286,516
# 304       Cedi Osman  CLE   $2,775,000
# 416           Salary  NaN          NaN
# 195     Jayson Tatum  BOS   $6,700,800
# 110   Nikola Vucevic  ORL  $12,750,000
# 401     Caris LeVert  BRK   $1,702,800
# 235   Jonathan Isaac  ORL   $4,969,080
# 241           Player   Tm      2018-19
# 269  Michael Beasley  LAC   $3,500,000
# 543    Edmond Sumner  IND     $449,794
# 547      C.J. Watson  ORL     $333,333
# 43            Player   Tm      2018-19
# Enter a player: Jahlil Okafor
#             Player Team     2018-19
# 426  Jahlil Okafor  NOP  $1,567,007
# Enter that player's salary: 1
# You have used $7 and have $139999993 left
#               Player Team      2018-19
# 569    Cameron Payne  CLE     $177,063
# 102      Eric Gordon  HOU  $13,500,375
# 504           Salary  NaN          NaN
# 347  Wayne Ellington  DET   $2,383,076
# 478     Daniel Theis  BOS   $1,378,242
# 145      Danny Green  TOR  $10,000,000
# 196           Salary  NaN          NaN
# 56     Dwight Howard  BRK  $18,919,725
# 567     Ray Spalding  PHO     $184,746
# 405    Derrick White  SAS   $1,667,160
# 35     Nicolas Batum  CHO  $24,000,000
# 142         Rudy Gay  SAS  $10,087,200
# 477     Semi Ojeleye  BOS   $1,378,242
# 96        Jeremy Lin  ATL  $13,768,421
# 449   Christian Wood  NOP   $1,512,601
# Enter a player: Jahlil Okafor
#             Player Team     2018-19
# 426  Jahlil Okafor  NOP  $1,567,007
# Enter that player's salary: 1
# You have used $8 and have $139999992 left
#               Player Team      2018-19
# 314     Delon Wright  MEM   $2,536,898
# 375    Spencer Hawes  MIL   $2,007,058
# 440  Rodney McGruder  LAC   $1,544,951
# 524    Patrick McCaw  TOR     $786,000
# 120    Avery Bradley  MEM  $12,000,000
# 161    Kyle Anderson  MEM   $8,641,000
# 255    Collin Sexton  CLE   $4,068,600
# 316      Dario Saric  MIN   $2,526,840
# 163  Markieff Morris  NOP   $8,600,000
# 153           Player   Tm      2018-19
# 428      Salah Mejri  DAL   $1,567,007
# 32        Marc Gasol  TOR  $24,119,025
# 495      Isaac Bonga  LAL   $1,000,000
# 259     Dennis Smith  NYK   $3,819,960
# 47     Ryan Anderson  MIA  $20,421,546
# Enter a player: Jahlil Okafor
#             Player Team     2018-19
# 426  Jahlil Okafor  NOP  $1,567,007
# Enter that player's salary: 1
# You have used $9 and have $139999991 left
#                  Player Team      2018-19
# 231    Patrick Beverley  LAC   $5,027,028
# 555  Miroslav Raduljica  LAC     $252,043
# 495         Isaac Bonga  LAL   $1,000,000
# 478        Daniel Theis  BOS   $1,378,242
# 239           Ron Baker  NYK   $4,544,400
# 144      Andre Roberson  OKC  $10,000,000
# 23          Joel Embiid  PHI  $25,467,250
# 357         Harry Giles  SAC   $2,207,040
# 540       Chris Boucher  TOR     $457,418
# 321      Reggie Bullock  LAL   $2,500,000
# 470           Ivan Rabb  MEM   $1,378,242
# 308          Troy Brown  WAS   $2,749,080
# 580        Tyler Zeller  ATL     $106,974
# 312        Jerian Grant  ORL   $2,639,314
# 184         Jae Crowder  UTA   $7,305,825
# Enter a player: Jahlil Okafor
#             Player Team     2018-19
# 426  Jahlil Okafor  NOP  $1,567,007
# Enter that player's salary: 1
# You have used $10 and have $139999990 left
#                  Player Team      2018-19
# 378        Corey Brewer  SAC   $2,000,000
# 410         Jacob Evans  GSW   $1,644,240
# 143           Jon Leuer  DET  $10,002,681
# 208    Jonathon Simmons  PHI   $6,000,000
# 265        Zach Collins  POR   $3,628,920
# 178  Karl-Anthony Towns  MIN   $7,839,435
# 266      Frank Kaminsky  CHO   $3,627,842
# 570              Salary  NaN          NaN
# 615              Player   Tm      2018-19
# 477        Semi Ojeleye  BOS   $1,378,242
# 77          Ian Mahinmi  WAS  $15,944,154
# 132         John Henson  CLE  $11,327,466
# 491       Jalen Brunson  DAL   $1,230,000
# 217        Alex Abrines  OKC   $5,455,236
# 16          Otto Porter  CHI  $26,011,913
# Enter a player: Jahlil Okafor
#             Player Team     2018-19
# 426  Jahlil Okafor  NOP  $1,567,007
# Enter that player's salary: 1
# You have used $11 and have $139999989 left
#                 Player Team      2018-19
# 174             Salary  NaN          NaN
# 603       Garlon Green  NOP      $50,000
# 119      Austin Rivers  PHO  $12,000,000
# 583       John Jenkins  WAS      $99,290
# 490         Elie Okobo  PHO   $1,238,464
# 402       Jonah Bolden  PHI   $1,690,000
# 366          Raul Neto  UTA   $2,150,000
# 93           Luol Deng  LAL  $14,354,067
# 589  Demetrius Jackson  BOS      $92,857
# 321     Reggie Bullock  LAL   $2,500,000
# 107    Wilson Chandler  LAC  $12,800,562
# 412    DeAndre' Bembry  ATL   $1,634,640
# 232        Tony Parker  CHO   $5,000,000
# 409    Robert Williams  BOS   $1,654,440
# 433      Deyonta Davis  SAC   $1,544,951
# Enter a player: Jahlil Okafor
#             Player Team     2018-19
# 426  Jahlil Okafor  NOP  $1,567,007
# Enter that player's salary: 1
# You have used $12 and have $139999988 left
# Maximum players reached.
# ['Greg Monroe', 'Jahlil Okafor', 'Jahlil Okafor', 'Jahlil Okafor', 'Jahlil Okafor', 'Jahlil Okafor', 'Jahlil Okafor', 'Jahlil Okafor', 'Jahlil Okafor', 'Jahlil Okafor', 'Jahlil Okafor', 'Jahlil Okafor']
# Enter a player you selected or press 'quit': quit
